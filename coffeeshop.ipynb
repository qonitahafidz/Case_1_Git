# %% [markdown]
# <a href="https://colab.research.google.com/github/qonitahafidz/Case_1_Git/blob/main/coffeeshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
coffeeshop = pd.read_csv('Jumlah Rumah Kedai Kopi (Coffee Shop) Menurut Kelurahan, 2023.csv')

# %%
coffeeshop.dtypes
# Out:
# Kelurahan     object
# Unnamed: 1    object
# dtype: object

# %%
coffeeshop.shape
# Out:
# (61, 2)

# %%
#missing data
coffeeshop.isnull().sum()
# Out:
# Kelurahan     2
# Unnamed: 1    0
# dtype: int64

# %%
coffeeshop.isnull()
# Out:
#     Kelurahan  Unnamed: 1
# 0        True       False
# 1        True       False
# 2       False       False
# 3       False       False
# 4       False       False
# ..        ...         ...
# 56      False       False
# 57      False       False
# 58      False       False
# 59      False       False
# 60      False       False
#
# [61 rows x 2 columns]

# %%
coffeeshop
# Out:
#                Kelurahan                                         Unnamed: 1
# 0                    NaN  Jumlah Rumah Kedai Kopi (Coffee Shop) Menurut ...
# 1                    NaN                                               2023
# 2              1. Pajang                                                  5
# 3             2. Laweyan                                                  4
# 4                3. Bumi                                                  4
# ..                   ...                                                ...
# 56          12. Kadipiro                                                  -
# 57        13. Banyuanyar                                                  -
# 58             14. Joglo                                                  -
# 59        15. Banjarsari                                                  -
# 60  Kecamatan Banjarsari                                                 27
#
# [61 rows x 2 columns]

# %%
# Rename column name
coffeeshop.rename(columns={'Unnamed: 1': 'Jumlah Coffeeshop'}, inplace=True)

# %%
coffeeshop.dropna(subset=['Kelurahan'], inplace=True)
coffeeshop
# Out:
#                  Kelurahan Jumlah Coffeeshop
# 2                1. Pajang                 5
# 3               2. Laweyan                 4
# 4                  3. Bumi                 4
# 5             4. Panularan                 -
# 6             5. Sriwedari                 7
# 7             6. Penumping                15
# 8             7. Purwosari                11
# 9              8. Sondakan                 1
# 10               9. Kerten                 1
# 11               10. Jajar                 1
# 12          11. Karangasem                 1
# 13       Kecamatan Laweyan                50
# 14            1. Joyotakan                 -
# 15          2. Danukusuman                 5
# 16             3. Serengan                 -
# 17                4. Tipes                 3
# 18             5. Kratonan                 1
# 19             6. Jayengan                 2
# 20             7. Kemlayan                 7
# 21      Kecamatan Serengan                18
# ...

# %%
def assign_correct_kecamatan(coffeeshop):
    # Define the start of each kecamatan section by its first kelurahan
    kecamatan_boundaries = {
        '1. Pajang': 'Laweyan',
        '1. Joyotakan': 'Serengan',
        '1. Joyosuran': 'Pasar Kliwon',
        '1. Kepatihan Kulon': 'Jebres',
        '1. Mangkubumen': 'Banjarsari'
    }

    # Initialize empty list for kecamatan values
    kecamatan_values = []
    current_kecamatan = 'Laweyan'  # Start with Laweyan

    # Iterate through rows
    for index, row in coffeeshop.iterrows():
        kelurahan = row['Kelurahan']

        # Check if this kelurahan is a boundary marker
        if kelurahan in kecamatan_boundaries:
            current_kecamatan = kecamatan_boundaries[kelurahan]

        kecamatan_values.append(current_kecamatan)

    # Update the Kecamatan column
    coffeeshop['Kecamatan'] = kecamatan_values

    return coffeeshop

# %%
result_coffeeshop = assign_correct_kecamatan(coffeeshop)

print(result_coffeeshop)
# Out:
#                  Kelurahan Jumlah Coffeeshop     Kecamatan
# 2                1. Pajang                 5       Laweyan
# 3               2. Laweyan                 4       Laweyan
# 4                  3. Bumi                 4       Laweyan
# 5             4. Panularan                 -       Laweyan
# 6             5. Sriwedari                 7       Laweyan
# 7             6. Penumping                15       Laweyan
# 8             7. Purwosari                11       Laweyan
# 9              8. Sondakan                 1       Laweyan
# 10               9. Kerten                 1       Laweyan
# 11               10. Jajar                 1       Laweyan
# 12          11. Karangasem                 1       Laweyan
# 13       Kecamatan Laweyan                50       Laweyan
# 14            1. Joyotakan                 -      Serengan
# 15          2. Danukusuman                 5      Serengan
# 16             3. Serengan                 -      Serengan
# ...

# %%
coffeeshop
# Out:
#                  Kelurahan Jumlah Coffeeshop     Kecamatan
# 2                1. Pajang                 5       Laweyan
# 3               2. Laweyan                 4       Laweyan
# 4                  3. Bumi                 4       Laweyan
# 5             4. Panularan                 -       Laweyan
# 6             5. Sriwedari                 7       Laweyan
# 7             6. Penumping                15       Laweyan
# 8             7. Purwosari                11       Laweyan
# 9              8. Sondakan                 1       Laweyan
# 10               9. Kerten                 1       Laweyan
# 11               10. Jajar                 1       Laweyan
# 12          11. Karangasem                 1       Laweyan
# 13       Kecamatan Laweyan                50       Laweyan
# 14            1. Joyotakan                 -      Serengan
# 15          2. Danukusuman                 5      Serengan
# 16             3. Serengan                 -      Serengan
# ...

# %%
def clean_kelurahan_names(coffeeshop):
    # Function to remove numbers and dots from the beginning of strings
    def remove_number_prefix(text):
        # Split by dot and get the last part, then strip whitespace
        return text.split('.', 1)[-1].strip()

    # Apply the cleaning function to Kelurahan column
    coffeeshop['Kelurahan'] = coffeeshop['Kelurahan'].apply(remove_number_prefix)

    return coffeeshop

# %%
result_coffeeshop = clean_kelurahan_names(coffeeshop)

# Display the result
print(result_coffeeshop)
# Out:
#                  Kelurahan Jumlah Coffeeshop     Kecamatan
# 2                   Pajang                 5       Laweyan
# 3                  Laweyan                 4       Laweyan
# 4                     Bumi                 4       Laweyan
# 5                Panularan                 -       Laweyan
# 6                Sriwedari                 7       Laweyan
# 7                Penumping                15       Laweyan
# 8                Purwosari                11       Laweyan
# 9                 Sondakan                 1       Laweyan
# 10                  Kerten                 1       Laweyan
# 11                   Jajar                 1       Laweyan
# 12              Karangasem                 1       Laweyan
# 13       Kecamatan Laweyan                50       Laweyan
# 14               Joyotakan                 -      Serengan
# 15             Danukusuman                 5      Serengan
# 16                Serengan                 -      Serengan
# ...

# %%
def clean_and_remove_kecamatan_rows(coffeeshop):
    # First remove rows containing 'Kecamatan'
    coffeeshop = coffeeshop[~coffeeshop['Kelurahan'].str.contains('Kecamatan', na=False)]

    # Function to remove numbers and dots from the beginning of strings
    def remove_number_prefix(text):
        # Split by dot and get the last part, then strip whitespace
        return text.split('.', 1)[-1].strip()

    # Apply the cleaning function to Kelurahan column
    coffeeshop['Kelurahan'] = coffeeshop['Kelurahan'].apply(remove_number_prefix)

    # Reset the index
    coffeeshop = coffeeshop.reset_index(drop=True)

    return coffeeshop

# %%
result_coffeeshop = clean_and_remove_kecamatan_rows(coffeeshop)

# Display the result
print(result_coffeeshop)
# Out:
#            Kelurahan Jumlah Coffeeshop     Kecamatan
# 0             Pajang                 5       Laweyan
# 1            Laweyan                 4       Laweyan
# 2               Bumi                 4       Laweyan
# 3          Panularan                 -       Laweyan
# 4          Sriwedari                 7       Laweyan
# 5          Penumping                15       Laweyan
# 6          Purwosari                11       Laweyan
# 7           Sondakan                 1       Laweyan
# 8             Kerten                 1       Laweyan
# 9              Jajar                 1       Laweyan
# 10        Karangasem                 1       Laweyan
# 11         Joyotakan                 -      Serengan
# 12       Danukusuman                 5      Serengan
# 13          Serengan                 -      Serengan
# 14             Tipes                 3      Serengan
# 15          Kratonan                 1      Serengan
# 16          Jayengan                 2      Serengan
# ...

# %%
result_coffeeshop
# Out:
#            Kelurahan Jumlah Coffeeshop     Kecamatan
# 0             Pajang                 5       Laweyan
# 1            Laweyan                 4       Laweyan
# 2               Bumi                 4       Laweyan
# 3          Panularan                 -       Laweyan
# 4          Sriwedari                 7       Laweyan
# 5          Penumping                15       Laweyan
# 6          Purwosari                11       Laweyan
# 7           Sondakan                 1       Laweyan
# 8             Kerten                 1       Laweyan
# 9              Jajar                 1       Laweyan
# 10        Karangasem                 1       Laweyan
# 11         Joyotakan                 -      Serengan
# 12       Danukusuman                 5      Serengan
# 13          Serengan                 -      Serengan
# 14             Tipes                 3      Serengan
# 15          Kratonan                 1      Serengan
# 16          Jayengan                 2      Serengan
# ...

# %%
\\\\\\\\\\\\\\result_coffeeshop.to_csv('Jumlah Rumah Kedai Kopi (Coffee Shop) Menurut Kelurahan, 2023_end.csv', index=False)
