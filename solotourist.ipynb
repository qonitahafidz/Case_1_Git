# %% [markdown]
# <a href="https://colab.research.google.com/github/qonitahafidz/Case_1_Git/blob/main/solotourist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_wisatawan = pd.read_csv('Jumlah Pengunjung Daya Tarik Wisata, 2023.csv')

# %%
df_wisatawan.dtypes
# Out:
# Daya Tarik Wisata    object
# Unnamed: 1           object
# Unnamed: 2           object
# dtype: object

# %%
df_wisatawan.shape
# Out:
# (20, 3)

# %%
#missing data
df_wisatawan.isnull().sum()
# Out:
# Daya Tarik Wisata    3
# Unnamed: 1           0
# Unnamed: 2           1
# dtype: int64

# %%
df_wisatawan.isnull()
# Out:
#     Daya Tarik Wisata  Unnamed: 1  Unnamed: 2
# 0                True       False        True
# 1                True       False       False
# 2                True       False       False
# 3               False       False       False
# 4               False       False       False
# 5               False       False       False
# 6               False       False       False
# 7               False       False       False
# 8               False       False       False
# 9               False       False       False
# 10              False       False       False
# 11              False       False       False
# 12              False       False       False
# 13              False       False       False
# 14              False       False       False
# 15              False       False       False
# 16              False       False       False
# 17              False       False       False
# 18              False       False       False
# ...

# %%
df_wisatawan.rename(columns={'Unnamed: 1': 'Wisatawan Nusantara'}, inplace=True)

# %%
df_wisatawan.rename(columns={'Unnamed: 1': 'Wisatawan Nusantara', 'Unnamed: 2': 'Wisatawan Mancanegara'}, inplace=True)

# %%
df_wisatawan
# Out:
#                     Daya Tarik Wisata                  Wisatawan Nusantara  \
# 0                                 NaN  Jumlah Pengunjung Daya Tarik Wisata
# 1                                 NaN                  Wisatawan Nusantara
# 2                                 NaN                                 2023
# 3                        Obyek Wisata                                 9807
# 4   1. Kampung Situs Budaya Baluwarti                                    -
# 5            2. Kethoprak Balekambang                                    -
# 6                 3. Kraton Kasunanan                                    -
# 7                    4. Mangkunegaran                                 6392
# 8             5. Museum Radya Pustaka                                  528
# 9                6. Taman Balekambang                                    -
# 10                   7. W.O Sriwedari                                    -
# ...

# %%
df_wisatawan.dropna(subset=['Daya Tarik Wisata'], inplace=True)
df_wisatawan
# Out:
#                     Daya Tarik Wisata Wisatawan Nusantara  \
# 3                        Obyek Wisata                9807
# 4   1. Kampung Situs Budaya Baluwarti                   -
# 5            2. Kethoprak Balekambang                   -
# 6                 3. Kraton Kasunanan                   -
# 7                    4. Mangkunegaran                6392
# 8             5. Museum Radya Pustaka                 528
# 9                6. Taman Balekambang                   -
# 10                   7. W.O Sriwedari                   -
# 11                  8. THR. Sriwedari                   -
# 12         9. Museum Batik Danar Hadi                2673
# 13  10. Taman Satwataru (Solo Safari)                   -
# 14                   11. Museum Keris                 212
# 15               12. Museum Lokananta                   2
# 16       13. Masjid Raya Sheikh Zayed                   -
# 17                              Event                   2
# ...

# %%
df_wisatawan.drop(df_wisatawan.index[1], axis=0, inplace=True)

# %%
df_wisatawan
# Out:
#                     Daya Tarik Wisata Wisatawan Nusantara  \
# 3                        Obyek Wisata                9807
# 5            2. Kethoprak Balekambang                   -
# 6                 3. Kraton Kasunanan                   -
# 7                    4. Mangkunegaran                6392
# 8             5. Museum Radya Pustaka                 528
# 9                6. Taman Balekambang                   -
# 10                   7. W.O Sriwedari                   -
# 11                  8. THR. Sriwedari                   -
# 12         9. Museum Batik Danar Hadi                2673
# 13  10. Taman Satwataru (Solo Safari)                   -
# 14                   11. Museum Keris                 212
# 15               12. Museum Lokananta                   2
# 16       13. Masjid Raya Sheikh Zayed                   -
# 17                              Event                   2
# 18               14. Bakdan Neng Solo                   2
# ...

# %%
df_replacements = df_wisatawan.replace({'2. Kethoprak Balekambang': 'Kethoprak Balekambang', '3. Kraton Kasunanan': 'Kraton Kasunanan', '4. Mangkunegaran' : 'Mangkunegaran', '5. Museum Radya Pustaka' : 'Museum Radya Pustaka', '6. Taman Balekambang': 'Taman Balekambang', '7. W.O Sriwedari' : 'Wayang Orang Sriwedari', '8. THR. Sriwedari' : 'THR. Sriwedari','9. Museum Batik Danar Hadi': 'Museum Batik Danar Hadi', '10. Taman Satwataru (Solo Safari)': 'Taman Satwataru (Solo Safari)', '11. Museum Keris': 'Museum Keris', '12. Museum Lokananta': 'Museum Lokananta', '13. Masjid Raya Sheikh Zayed': 'Masjid Raya Sheikh Zayed', '14. Bakdan Neng Solo': 'Bakdan Neng Solo'})

# %%
df_replacements
# Out:
#                 Daya Tarik Wisata Wisatawan Nusantara Wisatawan Mancanegara
# 3                    Obyek Wisata                9807               3851647
# 5           Kethoprak Balekambang                   -                     -
# 6                Kraton Kasunanan                   -                     -
# 7                   Mangkunegaran                6392                143186
# 8            Museum Radya Pustaka                 528                 33683
# 9               Taman Balekambang                   -                     -
# 10         Wayang Orang Sriwedari                   -                 56206
# 11                 THR. Sriwedari                   -                     -
# 12        Museum Batik Danar Hadi                2673                 11074
# 13  Taman Satwataru (Solo Safari)                   -                557221
# 14                   Museum Keris                 212                 18953
# ...

# %%
df_replacements.to_csv('Daya Tarik Wisata_fix.csv', index=False)
